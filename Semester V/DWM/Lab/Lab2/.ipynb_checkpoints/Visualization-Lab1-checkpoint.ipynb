# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('winequality-red.csv')

# %% [markdown]
# Lab 2=>ploting the visiualization of the given data for interpritation

# %%
# Pie Chart of quality
quality_counts = df['quality'].value_counts()

# Create the pie chart
plt.figure(figsize=(8, 8))
plt.pie(quality_counts, labels=quality_counts.index, autopct='%1.1f%%', startangle=90)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Quality Distribution')
plt.show()

# %% [markdown]
# The inference from the above chart=>
# 1)the max wine is of quality 6 and 5

# %%
#Scatter graph
# Extract the "quality" and "pH" columns from the DataFrame
x = df['alcohol']
y = df['volatile acidity']

# Create the scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(x, y, marker='o', alpha=0.5)
plt.xlabel('alcohol')
plt.ylabel('volatile acidity')
plt.title('Scatter Plot: alcohol vs. volatile acidity')
plt.show()

# %% [markdown]
# From this we can see that even if the amount of alcohol increases the increase in acidity is insignificant

# %%
#Histograms
df.hist(figsize=(12, 10), bins=20)
plt.suptitle('Histograms for Numeric Features', fontsize=16)
plt.show()

# %% [markdown]
# This graph helps to understand the frequencies of the ranges of each features

# %%
#Bar chart
quality_counts = df['quality'].value_counts()
plt.figure(figsize=(8, 6))
plt.bar(quality_counts.index, quality_counts.values)
plt.xlabel('Quality')
plt.ylabel('Frequency')
plt.title('Bar Chart: Quality Distribution')
plt.show()

# %% [markdown]
# The inference from the above chart=> 1)the max wine is of quality 6 and 5

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df, figsize=(12, 12), diagonal='kde')
plt.suptitle('Scatter Matrix of Numeric Features', fontsize=16)
plt.show()

# %% [markdown]
# This each ith row and jth column represent how the ith attribute and jth attribute are related to each other
